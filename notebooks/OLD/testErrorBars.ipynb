# %%
import os
#NOTE CHANGE THIS TO THE PATH TO THE GITHUB FOLDER ON YOUR COMPUTER
os.chdir("C:/Users/matth/USRA2026/gaiadr3-analysis")
# !pip install -e .
import gaiadr3_analysis.gaia_input as gi
import gaiadr3_analysis.mean_photometry as mphot
import gaiadr3_analysis.epoch_photometry as ephot
# Out:
# Obtaining file:///C:/Users/matth/USRA2026/gaiadr3-analysis
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: astropy>=5.0 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gaiadr3-analysis==0.1.0) (7.2.0)
# Requirement already satisfied: numpy>=1.22 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gaiadr3-analysis==0.1.0) (2.4.1)
# Requirement already satisfied: pandas>=1.4 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gaiadr3-analysis==0.1.0) (2.3.3)
# Requirement already satisfied: matplotlib>=3.5 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gaiadr3-analysis==0.1.0) (3.10.8)
# Requirement already satisfied: scipy>=1.8 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gaiadr3-analysis==0.1.0) (1.17.1)
# Requirement already satisfied: astroquery>=0.4.8 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gaiadr3-analysis==0.1.0) (0.4.11)
# Requirement already satisfied: PyAstronomy>=0.18 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from gaiadr3-analysis==0.1.0) (0.25.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from astropy>=5.0->gaiadr3-analysis==0.1.0) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.10.27.0.39.10 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from astropy>=5.0->gaiadr3-analysis==0.1.0) (0.2026.5.11.1.8.52)
# Requirement already satisfied: PyYAML>=6.0.0 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from astropy>=5.0->gaiadr3-analysis==0.1.0) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from astropy>=5.0->gaiadr3-analysis==0.1.0) (25.0)
# Requirement already satisfied: requests>=2.19 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (2.32.5)
# Requirement already satisfied: beautifulsoup4>=4.8 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (4.14.3)
# Requirement already satisfied: html5lib>=0.999 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (1.1)
# Requirement already satisfied: keyring>=15.0 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (25.7.0)
# Requirement already satisfied: pyvo>=1.5 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (1.8.1)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from beautifulsoup4>=4.8->astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from beautifulsoup4>=4.8->astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (4.15.0)
# Requirement already satisfied: six>=1.9 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from html5lib>=0.999->astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (1.17.0)
# Requirement already satisfied: webencodings in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from html5lib>=0.999->astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (0.5.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from keyring>=15.0->astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (0.2.3)
# Requirement already satisfied: jaraco.classes in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from keyring>=15.0->astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (3.4.0)
# Requirement already satisfied: jaraco.functools in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from keyring>=15.0->astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (4.4.0)
# Requirement already satisfied: jaraco.context in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from keyring>=15.0->astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (6.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.5->gaiadr3-analysis==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.5->gaiadr3-analysis==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.5->gaiadr3-analysis==0.1.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.5->gaiadr3-analysis==0.1.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in C:\Users\matth\AppData\Roaming\Python\Python313\site-packages (from matplotlib>=3.5->gaiadr3-analysis==0.1.0) (10.4.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.5->gaiadr3-analysis==0.1.0) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.5->gaiadr3-analysis==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=1.4->gaiadr3-analysis==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=1.4->gaiadr3-analysis==0.1.0) (2025.3)
# Requirement already satisfied: quantities in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from PyAstronomy>=0.18->gaiadr3-analysis==0.1.0) (0.16.4)
# Requirement already satisfied: bidict in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from PyAstronomy>=0.18->gaiadr3-analysis==0.1.0) (0.23.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.19->astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.19->astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.19->astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.19->astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (2025.11.12)
# Requirement already satisfied: more-itertools in C:\Users\matth\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jaraco.classes->keyring>=15.0->astroquery>=0.4.8->gaiadr3-analysis==0.1.0) (11.0.2)
# Building wheels for collected packages: gaiadr3-analysis
#   Building editable for gaiadr3-analysis (pyproject.toml): started
#   Building editable for gaiadr3-analysis (pyproject.toml): finished with status 'done'
#   Created wheel for gaiadr3-analysis: filename=gaiadr3_analysis-0.1.0-0.editable-py3-none-any.whl size=11493 sha256=6a4e45d5d5a1fdaedd2787274a8673bb2e8efe69517c7e34ae92f5027ddcb640
#   Stored in directory: C:\Users\matth\AppData\Local\Temp\pip-ephem-wheel-cache-81djje1x\wheels\54\df\34\0c3b5acd0ac01a202089cadf06aad12d9206afd6e225727248
# Successfully built gaiadr3-analysis
# Installing collected packages: gaiadr3-analysis
#   Attempting uninstall: gaiadr3-analysis
#     Found existing installation: gaiadr3-analysis 0.1.0
#     Uninstalling gaiadr3-analysis-0.1.0:
#       Successfully uninstalled gaiadr3-analysis-0.1.0
# Successfully installed gaiadr3-analysis-0.1.0
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
adql = f"""
SELECT source_id, designation, ra, dec, parallax,
pmra, pmdec, phot_g_mean_mag, phot_bp_mean_mag,
phot_rp_mean_mag
FROM gaiadr3.gaia_source
WHERE source_id = 3667302325846472320
"""
test1 = gi.query_by_adql(adql)

# %%
mphot.ra_vs_dec(test1, error = True, title="ERROR BAR TEST 1")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 mphot.ra_vs_dec(test1, error = True, plot_title="RA vs Dec MiMes Survey Data")
#
# TypeError: ra_vs_dec() got an unexpected keyword argument 'plot_title'
