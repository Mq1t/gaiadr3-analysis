# %%
import sys
sys.path.append(r"C:\Users\choco\OneDrive\Documents\GitHub\gaiadr3-analysis")

import gaiadr3_analysis.gaia_input as gi
import importlib
importlib.reload(gi)

import time

# %%
gi.resolve_id("Proxima Centauri")
# Out:
# Resolved: 'Proxima Centauri' (Proxima Cen) -> Gaia DR3 5853498713190525696
# 5853498713190525696

# %%
ids = gi.resolve_id("Pleiades")
print(f"\nReturned {len(ids)} Gaia IDs")
# Out:
# Resolving 'Pleiades', membership_certainty >= 80:
#   -> 26874 raw membership link(s) from SIMBAD.
#   -> 4786 unique star name(s) after removing duplicates.
#   -> 4693 resolved to a Gaia DR3 ID (93 could not be resolved).
#              name common_name       gaia_id        binary_designations  \
# 0       *  16 Tau     Celaeno  6.528746e+16                ** HL    6A
# 1       *  17 Tau     Electra  6.527200e+16                        NaN
# 2       *  18 Tau         NaN  6.981295e+16                ** HL    8A
# 3       *  20 Tau        Maia  6.528323e+16                        NaN
# 4       *  21 Tau    Asterope  6.679850e+16  ** HJL 1026A; ** HL   12A
# ...           ...         ...           ...                        ...
# 4781  V* V610 Tau         NaN           NaN                ** CDM   21
# 4782  V* V642 Tau         NaN           NaN                ** BOV   15
# 4783  V* V646 Tau         NaN           NaN                ** BOV   19
# 4784  V* V669 Tau         NaN           NaN                        NaN
# 4785  V* V727 Tau         NaN           NaN                        NaN
#
#              ra        dec
# 0     56.200896  24.289468
# 1     56.218905  24.113338
# 2     56.290584  24.839262
# 3     56.456701  24.367744
# 4     56.476985  24.554510
# ...         ...        ...
# 4781        NaN        NaN
# 4782        NaN        NaN
# 4783        NaN        NaN
# 4784        NaN        NaN
# 4785        NaN        NaN
#
# [4786 rows x 6 columns]
# Could not resolve 93 child(ren) of 'Pleiades': ['2MASS J03263023+2830134', '2MASS J03444443+2255517', '2MASS J03474624+2255388', '2MASS J03553662+2247233', '2MASS J04001381+2425415', '2MASS J04080793+2614365', 'BD+22   578', 'BD+23   502', 'Cl Melotte   22  1005', 'Cl Melotte   22   370', 'Cl Melotte   22   885', 'Cl* Melotte   22    BPL     198', 'Cl* Melotte   22    BPL     249', 'Cl* Melotte   22    BPL     298', 'Cl* Melotte   22    BPL     317', 'Cl* Melotte   22    BPL     335', 'Cl* Melotte   22    BRB      16', 'Cl* Melotte   22    BRB      17', 'Cl* Melotte   22    BRB      21', 'Cl* Melotte   22    BRB      23', 'Cl* Melotte   22    BRB      28', 'Cl* Melotte   22    BRB      29', 'Cl* Melotte   22     DH     437', 'Cl* Melotte   22     DH     446', 'Cl* Melotte   22     DH     543', 'Cl* Melotte   22     DH      55', 'Cl* Melotte   22     DH     864', 'Cl* Melotte   22     DH     896', 'Cl* Melotte   22     DH     897', 'Cl* Melotte   22     DH     912', 'Cl* Melotte   22    HAR      18', 'Cl* Melotte   22    HHJ     189', 'Cl* Melotte   22    HHJ     271', 'Cl* Melotte   22    HHJ     292', 'Cl* Melotte   22    HHJ     308', 'Cl* Melotte   22    HHJ      56', 'Cl* Melotte   22    IPL      20', 'Cl* Melotte   22    IPL      25', 'Cl* Melotte   22    MSK      17', 'Cl* Melotte   22  NPNPL       2', 'Cl* Melotte   22   PELS      31', 'Cl* Melotte   22   PLIZ    1262', 'Cl* Melotte   22   PLIZ      16', 'Cl* Melotte   22   PLIZ      20', 'Cl* Melotte   22   PLIZ    2141', 'Cl* Melotte   22   PLIZ      28', 'Cl* Melotte   22   PLIZ      35', 'Cl* Melotte   22  ROQUE       4', 'Cl* Melotte   22    SHF      14', 'Cl* Melotte   22    SHF      15', 'Cl* Melotte   22    SHF      17', 'Cl* Melotte   22    SHF       3', 'Cl* Melotte   22    SHF      30', 'Cl* Melotte   22    SHF      34', 'Cl* Melotte   22    SHF      46', 'Cl* Melotte   22    SHF      47', 'Cl* Melotte   22    SHF      55', 'Cl* Melotte   22     SK     152', 'Cl* Melotte   22     SK     220', 'Cl* Melotte   22     SK      40', 'Cl* Melotte   22    SRS   41773', 'Gaia DR2 167151404084403840', 'HAT 259-09060', 'HD  23479', 'HD 282960', 'LP  357-168', 'LSPM J0358+2503', 'UCAC4 552-007662', 'UCAC4 561-008354', 'UCAC4 565-008567', 'UCAC4 570-010080', 'UCAC4 576-008445', 'UCAC4 576-009917', 'UGCS J034350.15+241229.7', 'UGCS J034929.70+221813.2', 'V* KM Tau', 'V* LZ Tau', 'V* MZ Tau', 'V* OX Tau', 'V* V1279 Tau', 'V* V344 Tau', 'V* V371 Tau', 'V* V404 Tau', 'V* V434 Tau', 'V* V444 Tau', 'V* V475 Tau', 'V* V504 Tau', 'V* V515 Tau', 'V* V610 Tau', 'V* V642 Tau', 'V* V646 Tau', 'V* V669 Tau', 'V* V727 Tau']
# Returned 4693 Gaia IDs

# %%
ids = gi.resolve_id(
    "Pleiades",
    center_ra=56.75,
    center_dec=24.12,
    radius_deg=3
)
print(f"\nReturned {len(ids)} Gaia IDs within radius")
# Out:
# Resolving 'Pleiades', membership_certainty >= 80:
#   -> 26874 raw membership link(s) from SIMBAD.
#   -> 4786 unique star name(s) after removing duplicates.
#   -> 4693 resolved to a Gaia DR3 ID (93 could not be resolved).
#   -> 2317 final, after dropping 2469 outside 3 deg of (ra=56.75, dec=24.12).
#              name common_name       gaia_id        binary_designations  \
# 0       *  16 Tau     Celaeno  6.528746e+16                ** HL    6A
# 1       *  17 Tau     Electra  6.527200e+16                        NaN
# 2       *  18 Tau         NaN  6.981295e+16                ** HL    8A
# 3       *  20 Tau        Maia  6.528323e+16                        NaN
# 4       *  21 Tau    Asterope  6.679850e+16  ** HJL 1026A; ** HL   12A
# ...           ...         ...           ...                        ...
# 2312  V* V610 Tau         NaN           NaN                ** CDM   21
# 2313  V* V642 Tau         NaN           NaN                ** BOV   15
# 2314  V* V646 Tau         NaN           NaN                ** BOV   19
# 2315  V* V669 Tau         NaN           NaN                        NaN
# 2316  V* V727 Tau         NaN           NaN                        NaN
#
#              ra        dec  separation_deg
# 0     56.200896  24.289468        0.528725
# 1     56.218905  24.113338        0.484784
# 2     56.290584  24.839262        0.831960
# 3     56.456701  24.367744        0.364550
# 4     56.476985  24.554510        0.500676
# ...         ...        ...             ...
# 2312        NaN        NaN             NaN
# 2313        NaN        NaN             NaN
# 2314        NaN        NaN             NaN
# 2315        NaN        NaN             NaN
# 2316        NaN        NaN             NaN
#
# [2317 rows x 7 columns]
# Could not resolve 93 child(ren) of 'Pleiades': ['2MASS J03263023+2830134', '2MASS J03444443+2255517', '2MASS J03474624+2255388', '2MASS J03553662+2247233', '2MASS J04001381+2425415', '2MASS J04080793+2614365', 'BD+22   578', 'BD+23   502', 'Cl Melotte   22  1005', 'Cl Melotte   22   370', 'Cl Melotte   22   885', 'Cl* Melotte   22    BPL     198', 'Cl* Melotte   22    BPL     249', 'Cl* Melotte   22    BPL     298', 'Cl* Melotte   22    BPL     317', 'Cl* Melotte   22    BPL     335', 'Cl* Melotte   22    BRB      16', 'Cl* Melotte   22    BRB      17', 'Cl* Melotte   22    BRB      21', 'Cl* Melotte   22    BRB      23', 'Cl* Melotte   22    BRB      28', 'Cl* Melotte   22    BRB      29', 'Cl* Melotte   22     DH     437', 'Cl* Melotte   22     DH     446', 'Cl* Melotte   22     DH     543', 'Cl* Melotte   22     DH      55', 'Cl* Melotte   22     DH     864', 'Cl* Melotte   22     DH     896', 'Cl* Melotte   22     DH     897', 'Cl* Melotte   22     DH     912', 'Cl* Melotte   22    HAR      18', 'Cl* Melotte   22    HHJ     189', 'Cl* Melotte   22    HHJ     271', 'Cl* Melotte   22    HHJ     292', 'Cl* Melotte   22    HHJ     308', 'Cl* Melotte   22    HHJ      56', 'Cl* Melotte   22    IPL      20', 'Cl* Melotte   22    IPL      25', 'Cl* Melotte   22    MSK      17', 'Cl* Melotte   22  NPNPL       2', 'Cl* Melotte   22   PELS      31', 'Cl* Melotte   22   PLIZ    1262', 'Cl* Melotte   22   PLIZ      16', 'Cl* Melotte   22   PLIZ      20', 'Cl* Melotte   22   PLIZ    2141', 'Cl* Melotte   22   PLIZ      28', 'Cl* Melotte   22   PLIZ      35', 'Cl* Melotte   22  ROQUE       4', 'Cl* Melotte   22    SHF      14', 'Cl* Melotte   22    SHF      15', 'Cl* Melotte   22    SHF      17', 'Cl* Melotte   22    SHF       3', 'Cl* Melotte   22    SHF      30', 'Cl* Melotte   22    SHF      34', 'Cl* Melotte   22    SHF      46', 'Cl* Melotte   22    SHF      47', 'Cl* Melotte   22    SHF      55', 'Cl* Melotte   22     SK     152', 'Cl* Melotte   22     SK     220', 'Cl* Melotte   22     SK      40', 'Cl* Melotte   22    SRS   41773', 'Gaia DR2 167151404084403840', 'HAT 259-09060', 'HD  23479', 'HD 282960', 'LP  357-168', 'LSPM J0358+2503', 'UCAC4 552-007662', 'UCAC4 561-008354', 'UCAC4 565-008567', 'UCAC4 570-010080', 'UCAC4 576-008445', 'UCAC4 576-009917', 'UGCS J034350.15+241229.7', 'UGCS J034929.70+221813.2', 'V* KM Tau', 'V* LZ Tau', 'V* MZ Tau', 'V* OX Tau', 'V* V1279 Tau', 'V* V344 Tau', 'V* V371 Tau', 'V* V404 Tau', 'V* V434 Tau', 'V* V444 Tau', 'V* V475 Tau', 'V* V504 Tau', 'V* V515 Tau', 'V* V610 Tau', 'V* V642 Tau', 'V* V646 Tau', 'V* V669 Tau', 'V* V727 Tau']
# Returned 2224 Gaia IDs within radius

# %%
gi.resolve_id("Proxima Centauri", sanity_check=True)
# Out:
# Resolved: 'Proxima Centauri' (Proxima Cen) -> Gaia DR3 5853498713190525696
# Sanity check: 1 source(s) checked, 0 flagged as possible mismatch(es).
# 5853498713190525696

# %%
df_star = gi.find_star(
    ra="14h29m42.9s",
    dec="-62d40m46s",
    degree_range=0.05,
    mag_min=0,
    mag_max=15,
    dist_min=1,
    dist_max=10
)
df_star
# Out:
# Cone search near (ra=217.4287, dec=-62.6794), radius 0.05 deg:
#   -> filter applied: phot_g_mean_mag >= 0 AND phot_g_mean_mag <= 15 AND parallax >= 100.0 AND parallax <= 1000.0
#   -> 1 source(s) found.
#            solution_id                   designation            source_id  \
# 0  1636148068921376768  Gaia DR3 5853498713190525696  5853498713190525696
#
#    common_name  random_index  ref_epoch          ra  ra_error        dec  \
# 0  Proxima Cen    1320081859     2016.0  217.392321  0.023999 -62.676075
#
#    dec_error  ...  azero_gspphot  azero_gspphot_lower  azero_gspphot_upper  \
# 0   0.034436  ...            0.0                  0.0               0.0001
#
#    ag_gspphot  ag_gspphot_lower  ag_gspphot_upper  ebpminrp_gspphot  \
# 0         0.0               0.0            0.0001               0.0
#
#    ebpminrp_gspphot_lower  ebpminrp_gspphot_upper  libname_gspphot
# 0                     0.0                  0.0001            MARCS
#
# [1 rows x 153 columns]

# %%
df_cluster = gi.find_cluster(
    ra=56.75,
    dec=24.12,
    search_radius_deg=3,
    top_n=10,
    min_membership_certainty=80
)
df_cluster
# Out:
# Cluster search near (ra=56.75, dec=24.12), radius 3 deg:
#   -> 8818 star(s) found.
#   -> skipped 996 member link(s) below membership_certainty 80.
#   -> grouped into 27 candidate cluster(s).
#   -> returning top 10 by member count.
#                   name common_name  member_count         ra        dec otype  \
# 0      Cl Melotte   22    Pleiades          2116  57.107415  24.115638   OpC
# 1   Sagittarius Stream         NaN           300  57.442219  23.754775   St*
# 2               UBC 31         NaN            76  57.746507  25.464379   OpC
# 3  [KC2019] Theia 1552         NaN            49  57.107185  23.598955   As*
# 4  [KC2019] Theia 1493         NaN            40  58.011117  23.709471   As*
# 5  [KC2019] Theia 1544         NaN            20  54.762712  24.719507   As*
# 6  [KC2019] Theia 1634         NaN            14  56.900225  22.477306   As*
# 7    [HR2023] HSC 1288         NaN             8  55.359067  24.541962   MGr
# 8      TAU-AUR T ASSOC         NaN             7  56.697993  21.935465   Cl*
# 9  [KC2019] Theia 1181         NaN             4  55.829196  24.398221   As*
#
#    separation_deg  implied_distance_pc
# 0        0.326245           138.270512
# 1        0.730528          3590.664273
# 2        1.620403           334.079444
# 3        0.614975           657.246139
# 4        1.223757           635.667292
# 5        1.906206           616.142945
# 6        1.648477           309.214595
# 7        1.335780           172.629580
# 8        2.185059          1204.819277
# 9        0.884394           168.139287

# %%
gi.sanity_check_star([2200858856019097088, 3017730821573167616])
# Out:
# Sanity check: 2 source(s) checked, 0 flagged as possible mismatch(es).
#                gaia_id common_name gaia_g_mag gaia_teff simbad_sp_type  \
# 0  2200858856019097088        None       None      None           None
# 1  3017730821573167616        None       None      None           None
#
#   simbad_v_mag flag
# 0         None
# 1         None

# %%
start = time.time()
ids = gi.resolve_id("Pleiades")
print(f"\nResolved {len(ids)} stars in {time.time() - start:.1f} seconds")
# Out:
# Resolving 'Pleiades', membership_certainty >= 80:
#   -> 26874 raw membership link(s) from SIMBAD.
#   -> 4786 unique star name(s) after removing duplicates.
#   -> 4693 resolved to a Gaia DR3 ID (93 could not be resolved).
#              name common_name       gaia_id        binary_designations  \
# 0       *  16 Tau     Celaeno  6.528746e+16                ** HL    6A
# 1       *  17 Tau     Electra  6.527200e+16                        NaN
# 2       *  18 Tau         NaN  6.981295e+16                ** HL    8A
# 3       *  20 Tau        Maia  6.528323e+16                        NaN
# 4       *  21 Tau    Asterope  6.679850e+16  ** HJL 1026A; ** HL   12A
# ...           ...         ...           ...                        ...
# 4781  V* V610 Tau         NaN           NaN                ** CDM   21
# 4782  V* V642 Tau         NaN           NaN                ** BOV   15
# 4783  V* V646 Tau         NaN           NaN                ** BOV   19
# 4784  V* V669 Tau         NaN           NaN                        NaN
# 4785  V* V727 Tau         NaN           NaN                        NaN
#
#              ra        dec
# 0     56.200896  24.289468
# 1     56.218905  24.113338
# 2     56.290584  24.839262
# 3     56.456701  24.367744
# 4     56.476985  24.554510
# ...         ...        ...
# 4781        NaN        NaN
# 4782        NaN        NaN
# 4783        NaN        NaN
# 4784        NaN        NaN
# 4785        NaN        NaN
#
# [4786 rows x 6 columns]
# Could not resolve 93 child(ren) of 'Pleiades': ['2MASS J03263023+2830134', '2MASS J03444443+2255517', '2MASS J03474624+2255388', '2MASS J03553662+2247233', '2MASS J04001381+2425415', '2MASS J04080793+2614365', 'BD+22   578', 'BD+23   502', 'Cl Melotte   22  1005', 'Cl Melotte   22   370', 'Cl Melotte   22   885', 'Cl* Melotte   22    BPL     198', 'Cl* Melotte   22    BPL     249', 'Cl* Melotte   22    BPL     298', 'Cl* Melotte   22    BPL     317', 'Cl* Melotte   22    BPL     335', 'Cl* Melotte   22    BRB      16', 'Cl* Melotte   22    BRB      17', 'Cl* Melotte   22    BRB      21', 'Cl* Melotte   22    BRB      23', 'Cl* Melotte   22    BRB      28', 'Cl* Melotte   22    BRB      29', 'Cl* Melotte   22     DH     437', 'Cl* Melotte   22     DH     446', 'Cl* Melotte   22     DH     543', 'Cl* Melotte   22     DH      55', 'Cl* Melotte   22     DH     864', 'Cl* Melotte   22     DH     896', 'Cl* Melotte   22     DH     897', 'Cl* Melotte   22     DH     912', 'Cl* Melotte   22    HAR      18', 'Cl* Melotte   22    HHJ     189', 'Cl* Melotte   22    HHJ     271', 'Cl* Melotte   22    HHJ     292', 'Cl* Melotte   22    HHJ     308', 'Cl* Melotte   22    HHJ      56', 'Cl* Melotte   22    IPL      20', 'Cl* Melotte   22    IPL      25', 'Cl* Melotte   22    MSK      17', 'Cl* Melotte   22  NPNPL       2', 'Cl* Melotte   22   PELS      31', 'Cl* Melotte   22   PLIZ    1262', 'Cl* Melotte   22   PLIZ      16', 'Cl* Melotte   22   PLIZ      20', 'Cl* Melotte   22   PLIZ    2141', 'Cl* Melotte   22   PLIZ      28', 'Cl* Melotte   22   PLIZ      35', 'Cl* Melotte   22  ROQUE       4', 'Cl* Melotte   22    SHF      14', 'Cl* Melotte   22    SHF      15', 'Cl* Melotte   22    SHF      17', 'Cl* Melotte   22    SHF       3', 'Cl* Melotte   22    SHF      30', 'Cl* Melotte   22    SHF      34', 'Cl* Melotte   22    SHF      46', 'Cl* Melotte   22    SHF      47', 'Cl* Melotte   22    SHF      55', 'Cl* Melotte   22     SK     152', 'Cl* Melotte   22     SK     220', 'Cl* Melotte   22     SK      40', 'Cl* Melotte   22    SRS   41773', 'Gaia DR2 167151404084403840', 'HAT 259-09060', 'HD  23479', 'HD 282960', 'LP  357-168', 'LSPM J0358+2503', 'UCAC4 552-007662', 'UCAC4 561-008354', 'UCAC4 565-008567', 'UCAC4 570-010080', 'UCAC4 576-008445', 'UCAC4 576-009917', 'UGCS J034350.15+241229.7', 'UGCS J034929.70+221813.2', 'V* KM Tau', 'V* LZ Tau', 'V* MZ Tau', 'V* OX Tau', 'V* V1279 Tau', 'V* V344 Tau', 'V* V371 Tau', 'V* V404 Tau', 'V* V434 Tau', 'V* V444 Tau', 'V* V475 Tau', 'V* V504 Tau', 'V* V515 Tau', 'V* V610 Tau', 'V* V642 Tau', 'V* V646 Tau', 'V* V669 Tau', 'V* V727 Tau']
# Resolved 4693 stars in 100.4 seconds
