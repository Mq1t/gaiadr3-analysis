# %%
#starting off by importing the necessary libraries, for this star we only need its epoch photometry data
import os
#Specifying the filepath needed to access the functions in the gaia_input and epoch_photometry files
os.chdir("C:/Users/nakia/OneDrive/Documents/GitHub/gaiadr3-analysis")
# !pip install -e .
#importing gaia_input and epoch_photometry files to access the functions within them
import gaiadr3_analysis.gaia_input as gi
import gaiadr3_analysis.epoch_photometry as ephot
# Out:
# Obtaining file:///C:/Users/nakia/OneDrive/Documents/GitHub/gaiadr3-analysis
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# ...
#   Building editable for gaiadr3-analysis (pyproject.toml): started
#   Building editable for gaiadr3-analysis (pyproject.toml): finished with status 'done'
#   Created wheel for gaiadr3-analysis: filename=gaiadr3_analysis-0.1.0-0.editable-py3-none-any.whl size=11567 sha256=df466d13bd353d3184399bb5cb763e62fa936b50dd66351b04c92408a2221c0b
# ...

# %%
#login to the Gaia Archive using credentials as it may resolve any access issues when querying using a datalink
gi.gaia_login_prompt()
# Out:
# INFO: Login to gaia TAP server [astroquery.gaia.core]
# INFO: OK [astroquery.utils.tap.core]
# INFO: Login to gaia data server [astroquery.gaia.core]
# INFO: OK [astroquery.utils.tap.core]
# Logged in to Gaia archive.

# %%
#Now querying the epoch photometry data for HD 13745 using a datalink from the Gaia archive.

#We must place the source id into a list and then convert it to a string ([ID]) next to the (ID) in order to have the proper formatting in a pandas dataframe.
df_datalink =  gi.query_by_datalink(456780633911740288)[456780633911740288]


#Each function is called using its respective module (epoch_photometry). In this example, we have imported the epoch_photometry module as ephot. Although it can be called whatever you want.
#The function is called using modname.function_name(parameters)
ephot.lightcurve(df_datalink, plot= True, title="Flux vs Time of the Star Example 2")
ephot.lomb_scargle(df_datalink['g_transit_time'], df_datalink['g_transit_mag'], plot = True, title="Lomb-Scargle Periodogram of the Star Example 2")
ephot.pdm(df_datalink['g_transit_time'], df_datalink['g_transit_mag'], plot = True, title="PDM Plot of the Star Example 2")
# Out:
# Len g, bp, and rp datasets respectively: 61, 61, 61
# Best period: 3.689154 days (88.540 hours)
# c:\Users\nakia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\PyAstronomy\pyTiming\pyPDM\pdm.py:183: RuntimeWarning: divide by zero encountered in scalar divide
#   sSqr = sSqrUp / sSqrDown
# c:\Users\nakia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\PyAstronomy\pyTiming\pyPDM\pdm.py:183: RuntimeWarning: divide by zero encountered in scalar divide
#   sSqr = sSqrUp / sSqrDown
# c:\Users\nakia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\PyAstronomy\pyTiming\pyPDM\pdm.py:183: RuntimeWarning: divide by zero encountered in scalar divide
#   sSqr = sSqrUp / sSqrDown
# c:\Users\nakia\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\PyAstronomy\pyTiming\pyPDM\pdm.py:183: RuntimeWarning: divide by zero encountered in scalar divide
#   sSqr = sSqrUp / sSqrDown
# ...
