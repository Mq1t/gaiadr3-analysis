# %%
import gaiadr3_analysis.gaia_input as gi
import gaiadr3_analysis.mean_photometry as mphot
import gaiadr3_analysis.epoch_photometry as mphot
import pandas as pd
import numpy as np
# Out:
# Maintenance with possible short-time disconnections: 29 June 2026 18:00–20:00 CEST

# %%
#Queries

#Query mean photometry from Gaia Archive

# %%
#Cross matching

# %%
#Epoch photometry

# %%
#Mean photometry
