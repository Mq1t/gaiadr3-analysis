# %%
import scatterplot
import lightcurve
import lombscargle
import pandas as pd

# %%
#beStar from earlier weeks
df = pd.read_csv('EPOCH_PHOTOMETRY-Gaia DR3 6237015550067390592.csv')
print("Rows: "+str(len(df)))
# Out:
# Rows: 39

# %%
#Test light curves
#plot_lightcurves(df:pd.DataFrame, g, bp, rp, g_time, bp_time, rp_time, title:str='Flux Vs. Time', overplot:bool=True, rejectflags: bool=False, period:float=None, xlim:float=None, ylim:float=None)
#Flux V. Time (uses only required variables)
lightcurve.plot_lightcurves(df, 'g_transit_mag', 'bp_mag', 'rp_mag', 'g_transit_time', 'bp_obs_time', 'rp_obs_time')

#Without overplot
lightcurve.plot_lightcurves(df, 'g_transit_mag', 'bp_mag', 'rp_mag', 'g_transit_time', 'bp_obs_time', 'rp_obs_time', overplot=False)
# Out:
# Len g, bp, and rp datasets respectively: 39, 39, 39
# Len g, bp, and rp datasets respectively: 39, 39, 39

# %%
#Test LS
#period(t: pd.DataFrame = None, mag: pd.DataFrame = None, frequency_range: list[float] = None, jd: bool=True):
#p = lombscargle.period(df['g_transit_time'], df['g_transit_mag'])

#plot(t: pd.DataFrame = None, mag: pd.DataFrame = None, frequency_range: list[float] = None, lims: list[float] = None, jd: bool=True)
p = lombscargle.plot(df['g_transit_time'], df['g_transit_mag'], lims=[0, 30])
# Out:
# Best period: 0.508315 days (12.200 hours)
# 1. Period: 0.508315 days (12.200 hours), Power: 0.586107, FAP: 5.911787318494385e-05
# 2. Period: 0.508259 days (12.198 hours), Power: 0.563041, FAP: 0.00014969440147783627
# 3. Period: 0.508371 days (12.201 hours), Power: 0.475684, FAP: 0.0033362606398781225
# 4. Period: 0.508203 days (12.197 hours), Power: 0.455774, FAP: 0.006261006143658548
# 5. Period: 0.361261 days (8.670 hours), Power: 0.392552, FAP: 0.039117939152807854

# %%
lightcurve.plot_lightcurves(df, 'g_transit_mag', 'bp_mag', 'rp_mag', 'g_transit_time', 'bp_obs_time', 'rp_obs_time', overplot=False, period=p)
# Out:
# Len g, bp, and rp datasets respectively: 39, 39, 39
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 lightcurve.plot_lightcurves(df, 'g_transit_mag', 'bp_mag', 'rp_mag', 'g_transit_time', 'bp_obs_time', 'rp_obs_time', overplot=False, period=p)
#
# File ~\USRA2026\gaiadr3-analysis\lightcurve.py:33, in plot_lightcurves(df, g, bp, rp, g_time, bp_time, rp_time, title, overplot, rejectflags, period, xlim, ylim)
#      31     x_bp = phase(x_bp, x_g.median(), period)
#      32     x_rp = phase(x_rp, x_g.median(), period)
# ---> 33     x_label = f"Phase, p = {p}"
#      34     print(f"P value: {p}")
#      36 #Y-Value: Magnitudes for light band
#
# NameError: name 'p' is not defined
